# %% [markdown]
# # Creating New Data Frame for the Control Group for Questionnaire_datasetIA

# %% [markdown]
# Merging all the numerical and categorical columns and named the dataset as 'merged control.csv'

# %%
import pandas as pd # my dataframe with extented empathy score for IA(even)

# Load the first CSV file
df1 = pd.read_csv('numeric_values.csv')

# Load the second CSV file
df2 = pd.read_csv('categorical_values.csv')

# Merge the two dataframes based on the 'participant_nr' column
merged_df = pd.merge(df1, df2, on='File Name')

# Save the merged dataframe to a new CSV file
merged_df.to_csv('merged control.csv', index=False)

# %% [markdown]
# From the dataset 'Questionnaire_datasetIA.csv' extracting the columns 'Participant nr' and 'Total Score original'

# %% [markdown]
# Make a dataset named as 'empathy extended score IA.csv'

# %%
import pandas as pd # modifiy the IA csv file with even number with 'Participant nr','Total Score extended'

# Read in the CSV file with the correct encoding
df = pd.read_csv('Questionnaire_datasetIA.csv', encoding='Windows-1252')

# Create a new DataFrame with just the two columns you want
new_df = df[['Participant nr','Total Score original']]
# Filter out rows with odd participant numbers
new_df = new_df[new_df['Participant nr'] % 2 == 0]

# Write the new DataFrame to a CSV file
new_df.to_csv('empathy orginal score IA.csv', index=False)

# %% [markdown]
# Merging the column 'Participant nr' and the dataset 'merged control.csv'. Name the merged dataset
# as 'merged CG original score with participant nr.csv'

# %%
import pandas as pd # file namewise participent number
import re

# Load your data into a dataframe
df = pd.read_csv('merged control.csv')

# Define a regular expression to match the number in the file name
pattern = r'\d+'

# Extract the number from each file name and create a new column 'nr'
df['Participant nr'] = df['File Name'].apply(lambda x: int(re.search(pattern, x).group()))

df.to_csv('merged CG original score with participant nr.csv', index=False)

# %% [markdown]
# Merging the previous two data set 'merged CG original score with participant nr.csv' and 'empathy extended score IA.csv' creating
# the final dataframe as 'New dataframe for the Control Group of original score.csv'.

# %%
import pandas as pd # my dataframe with extented empathy score for IA(even)

# Load the first CSV file
df1 = pd.read_csv('merged CG original score with participant nr.csv')

# Load the second CSV file
df2 = pd.read_csv('empathy orginal score IA.csv')

# Merge the two dataframes based on the 'participant_nr' column
merged_df = pd.merge(df1, df2, on='Participant nr')

# Save the merged dataframe to a new CSV file
merged_df.to_csv('New dataframe for the Control Group of original score.csv', index=False)

# %%
merged_df.shape
# Out:
# (142, 49)

# %%
merged_df.head()
# Out:
#                                            File Name  \
# 0  EyeT_group_dataset_II_image_name_grey_blue_par...
# 1  EyeT_group_dataset_II_image_name_grey_blue_par...
# 2  EyeT_group_dataset_II_image_name_grey_blue_par...
# 3  EyeT_group_dataset_II_image_name_grey_blue_par...
# 4  EyeT_group_dataset_II_image_name_grey_blue_par...
#
#    Recording timestamp Mean  Eye movement type index Mean  Gaze point X std  \
# 0              3.433023e+07                     99.325672        263.417383
# 1              3.597488e+07                     97.691612        285.985660
# 2              3.730088e+07                     98.543349        449.928319
# 3              2.760638e+07                     62.041311        422.168612
# 4              4.642052e+07                   1131.761687        145.098913
#
#    Gaze point Y std  Gaze point left X std  Gaze point left Y std  \
# 0        184.022517             266.123348             186.790705
# 1        229.681948             290.183399             228.411449
# 2        296.600542             454.054157             292.848413
# 3        291.750382             425.820691             292.843381
# 4        191.266395             144.758837             190.017291
#
#    Gaze point right X std  Gaze point right Y std  Fixation point X std  ...  \
# 0              260.009995              181.425624            263.789115  ...
# 1              291.828613              225.005425            289.322105  ...
# 2              336.000224              241.876018            451.336330  ...
# 3              417.786224              289.088964            417.652184  ...
# 4              144.851690              191.268911            140.586349  ...
#
#    Gaze point left Y (MCSnorm) std  Gaze point right X (MCSnorm) std  \
# 0                       998.498528                        892.535726
# 1                      1019.156885                        922.290747
# 2                      1115.153046                        618.195177
# 3                       812.663985                        689.703259
# 4                       866.400883                        500.304828
#
#    Gaze point right Y (MCSnorm) std  Fixation point X (MCSnorm) std  \
# 0                        939.216928                       47.004623
# 1                       1061.481171                       39.226810
# 2                        710.900950                       43.546304
# 3                        769.998594                       26.073817
# 4                        714.166929                       14.823745
#
#    Fixation point Y (MCSnorm) std  Validity left count  Validity right count  \
# 0                       48.309219                 7222                  7222
# 1                       40.479258                 7296                  7296
# 2                       42.750270                 7255                  7255
# 3                       27.522852                 6100                  6100
# 4                       15.325697                 9605                  9605
#
#    Eye movement type count  Participant nr  Total Score original
# 0                     7222              10                    82
# 1                     7296              10                    82
# 2                     7255              10                    82
# 3                     6100              10                    82
# 4                     9605              14                   105
#
# [5 rows x 49 columns]

# %%
# Dropping the column 'File Name' and 'Participant nr'
new_df = merged_df.drop(['File Name', 'Participant nr'], axis=1)

# %%
new_df
# Out:
#      Recording timestamp Mean  Eye movement type index Mean  Gaze point X std  \
# 0                3.433023e+07                     99.325672        263.417383
# 1                3.597488e+07                     97.691612        285.985660
# 2                3.730088e+07                     98.543349        449.928319
# 3                2.760638e+07                     62.041311        422.168612
# 4                4.642052e+07                   1131.761687        145.098913
# ..                        ...                           ...               ...
# 137              3.454407e+07                    123.696540        348.195147
# 138              3.551248e+07                    188.272075        269.608525
# 139              4.271202e+07                    257.791912        264.456991
# 140              3.457366e+07                    234.419286        290.229193
# 141              3.266546e+07                    312.893088        336.061728
#
#      Gaze point Y std  Gaze point left X std  Gaze point left Y std  \
# 0          184.022517             266.123348             186.790705
# 1          229.681948             290.183399             228.411449
# 2          296.600542             454.054157             292.848413
# 3          291.750382             425.820691             292.843381
# 4          191.266395             144.758837             190.017291
# ..                ...                    ...                    ...
# 137        263.231043             348.720574             266.853183
# 138        300.558986             271.133153             298.431022
# 139        268.899033             270.310276             267.858520
# 140        276.130932             295.652202             274.167354
# 141        320.260789             343.123426             325.584783
#
#      Gaze point right X std  Gaze point right Y std  Fixation point X std  \
# 0                260.009995              181.425624            263.789115
# 1                291.828613              225.005425            289.322105
# 2                336.000224              241.876018            451.336330
# 3                417.786224              289.088964            417.652184
# 4                144.851690              191.268911            140.586349
# ..                      ...                     ...                   ...
# 137              359.437361              269.704541            318.768719
# 138              267.432735              300.266022            202.240151
# 139              255.786411              268.392691            218.218237
# 140              278.200379              278.856312            232.850603
# 141              340.615397              316.919569            273.884071
#
#      Fixation point Y std  ...  Gaze point left X (MCSnorm) std  \
# 0              181.442909  ...                       914.774328
# 1              222.149891  ...                       911.315023
# 2              291.431232  ...                      1087.324546
# 3              286.011741  ...                       715.041518
# 4              192.131189  ...                       559.320141
# ..                    ...  ...                              ...
# 137            262.027804  ...                      1086.368688
# 138            264.436224  ...                       997.211804
# 139            255.283896  ...                      1024.940335
# 140            258.327262  ...                       863.540734
# 141            247.208021  ...                       833.848432
#
#      Gaze point left Y (MCSnorm) std  Gaze point right X (MCSnorm) std  \
# 0                         998.498528                        892.535726
# 1                        1019.156885                        922.290747
# 2                        1115.153046                        618.195177
# 3                         812.663985                        689.703259
# 4                         866.400883                        500.304828
# ..                               ...                               ...
# 137                       997.565094                       1069.764207
# 138                      1090.325773                       1034.690912
# 139                      1014.530252                       1108.573224
# 140                       940.222160                        961.075614
# 141                       846.563440                       1005.467151
#
#      Gaze point right Y (MCSnorm) std  Fixation point X (MCSnorm) std  \
# 0                          939.216928                       47.004623
# 1                         1061.481171                       39.226810
# 2                          710.900950                       43.546304
# 3                          769.998594                       26.073817
# 4                          714.166929                       14.823745
# ..                                ...                             ...
# 137                       1030.860348                       41.084894
# 138                       1148.950074                       37.916347
# 139                       1155.032959                       54.374087
# 140                       1087.453509                       34.966950
# 141                       1032.868704                       30.226440
#
#      Fixation point Y (MCSnorm) std  Validity left count  \
# 0                         48.309219                 7222
# 1                         40.479258                 7296
# 2                         42.750270                 7255
# 3                         27.522852                 6100
# 4                         15.325697                 9605
# ..                              ...                  ...
# 137                       41.397785                 7398
# 138                       42.991139                 7248
# 139                       56.560900                 8828
# 140                       42.334175                 7446
# 141                       30.302762                 7118
#
#      Validity right count  Eye movement type count  Total Score original
# 0                    7222                     7222                    82
# 1                    7296                     7296                    82
# 2                    7255                     7255                    82
# 3                    6100                     6100                    82
# 4                    9605                     9605                   105
# ..                    ...                      ...                   ...
# 137                  7398                     7398                   105
# 138                  7248                     7248                    89
# 139                  8828                     8828                    89
# 140                  7446                     7446                    89
# 141                  7118                     7118                    89
#
# [142 rows x 47 columns]

# %% [markdown]
# Fitting the dataframe into the Random Forest Classifier using leave-one-out cross-validation iterator.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import LeaveOneOut

# Assuming your dataset is already imported into a Pandas dataframe called `new_df`
X = new_df.drop("Total Score original", axis=1) # assuming the name of the target variable is 'target_variable'
y = new_df["Total Score original"]

# Create an instance of the Random Forest model
rf = RandomForestClassifier()

# Create a leave-one-out cross-validation iterator
loo = LeaveOneOut()

# Initialize an empty list to store the scores
scores = []

# Iterate over the splits and train/validate the model
for train_index, test_index in loo.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    rf.fit(X_train, y_train)
    score = rf.score(X_test, y_test)
    scores.append(score)

# Compute the mean score across all splits
mean_score = sum(scores) / len(scores)
print("Mean accuracy:", mean_score)
# Out:
# Mean accuracy: 0.4225352112676056

# %% [markdown]
# Fitting the dataframe into the Logistic Regression using leave-one-out cross-validation iterator.

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import LeaveOneOut

# Assuming your dataset is already imported into a Pandas dataframe called `new_df`
X = new_df.drop("Total Score original", axis=1) # assuming the name of the target variable is 'target_variable'
y = new_df["Total Score original"]

# Create an instance of the logistic regression model
logreg = LogisticRegression()

# Create a leave-one-out cross-validation iterator
loo = LeaveOneOut()

# Initialize an empty list to store the scores
scores = []

# Iterate over the splits and train/validate the model
for train_index, test_index in loo.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    logreg.fit(X_train, y_train)
    score = logreg.score(X_test, y_test)
    scores.append(score)

# Compute the mean score across all splits
mean_score = sum(scores) / len(scores)
print("Mean accuracy:", mean_score)
# Out:
# Mean accuracy: 0.14788732394366197

# %% [markdown]
#  # Creating New Data Frame for Questionnaire_datasetIB

# %% [markdown]
# Merging all the data set 'Questionnaire_datasetIB.csv' and the column 'Participant nr' and 'Total Score original'
# and named the dataset as 'empathy original score IB.csv'.

# %%
import pandas as pd # modifiy the IA csv file with even number with 'Participant nr','Total Score extended'

# Read in the CSV file with the correct encoding
df = pd.read_csv('Questionnaire_datasetIB.csv', encoding='Windows-1252')

# Create a new DataFrame with just the two columns you want
new_df = df[['Participant nr','Total Score original']]
# Filter out rows with odd participant numbers
new_df = new_df[new_df['Participant nr'] % 2 == 0]

# Write the new DataFrame to a CSV file
new_df.to_csv('empathy original score IB.csv', index=False)

# %% [markdown]
# Merging the column 'Participant nr' and the dataset 'merged control.csv'. Name the merged dataset
# as 'merged CG with participant nr.csv'

# %%
import pandas as pd # file namewise participent number
import re

# Load your data into a dataframe
df = pd.read_csv('merged control.csv')

# Define a regular expression to match the number in the file name
pattern = r'\d+'

# Extract the number from each file name and create a new column 'nr'
df['Participant nr'] = df['File Name'].apply(lambda x: int(re.search(pattern, x).group()))

df.to_csv('merged CG with participant nr.csv', index=False)

# %% [markdown]
# Merging the previous two data set 'merged CG with participant nr.csv'and 'empathy extended score IB.csv' creating
# the final dataframe as 'New dataframe for the Control Group1B.csv'.

# %%
import pandas as pd # my dataframe with extented empathy score for IA(even)

# Load the first CSV file
df1 = pd.read_csv('merged CG with participant nr.csv')

# Load the second CSV file
df2 = pd.read_csv('empathy original score IB.csv')

# Merge the two dataframes based on the 'participant_nr' column
merged_df = pd.merge(df1, df2, on='Participant nr')

# Save the merged dataframe to a new CSV file
merged_df.to_csv('New dataframe for the Control Group of original score1B.csv', index=False)

# %%
merged_df.shape
# Out:
# (142, 49)

# %%
merged_df.head()
# Out:
#                                            File Name  \
# 0  EyeT_group_dataset_II_image_name_grey_blue_par...
# 1  EyeT_group_dataset_II_image_name_grey_blue_par...
# 2  EyeT_group_dataset_II_image_name_grey_blue_par...
# 3  EyeT_group_dataset_II_image_name_grey_blue_par...
# 4  EyeT_group_dataset_II_image_name_grey_blue_par...
#
#    Recording timestamp Mean  Eye movement type index Mean  Gaze point X std  \
# 0              3.433023e+07                     99.325672        263.417383
# 1              3.597488e+07                     97.691612        285.985660
# 2              3.730088e+07                     98.543349        449.928319
# 3              2.760638e+07                     62.041311        422.168612
# 4              4.642052e+07                   1131.761687        145.098913
#
#    Gaze point Y std  Gaze point left X std  Gaze point left Y std  \
# 0        184.022517             266.123348             186.790705
# 1        229.681948             290.183399             228.411449
# 2        296.600542             454.054157             292.848413
# 3        291.750382             425.820691             292.843381
# 4        191.266395             144.758837             190.017291
#
#    Gaze point right X std  Gaze point right Y std  Fixation point X std  ...  \
# 0              260.009995              181.425624            263.789115  ...
# 1              291.828613              225.005425            289.322105  ...
# 2              336.000224              241.876018            451.336330  ...
# 3              417.786224              289.088964            417.652184  ...
# 4              144.851690              191.268911            140.586349  ...
#
#    Gaze point left Y (MCSnorm) std  Gaze point right X (MCSnorm) std  \
# 0                       998.498528                        892.535726
# 1                      1019.156885                        922.290747
# 2                      1115.153046                        618.195177
# 3                       812.663985                        689.703259
# 4                       866.400883                        500.304828
#
#    Gaze point right Y (MCSnorm) std  Fixation point X (MCSnorm) std  \
# 0                        939.216928                       47.004623
# 1                       1061.481171                       39.226810
# 2                        710.900950                       43.546304
# 3                        769.998594                       26.073817
# 4                        714.166929                       14.823745
#
#    Fixation point Y (MCSnorm) std  Validity left count  Validity right count  \
# 0                       48.309219                 7222                  7222
# 1                       40.479258                 7296                  7296
# 2                       42.750270                 7255                  7255
# 3                       27.522852                 6100                  6100
# 4                       15.325697                 9605                  9605
#
#    Eye movement type count  Participant nr  Total Score original
# 0                     7222              10                    76
# 1                     7296              10                    76
# 2                     7255              10                    76
# 3                     6100              10                    76
# 4                     9605              14                   102
#
# [5 rows x 49 columns]

# %%
# Dropping the column 'File Name' and 'Participant nr'.
new_df = merged_df.drop(['File Name', 'Participant nr'], axis=1)

# %%
new_df
# Out:
#      Recording timestamp Mean  Eye movement type index Mean  Gaze point X std  \
# 0                3.433023e+07                     99.325672        263.417383
# 1                3.597488e+07                     97.691612        285.985660
# 2                3.730088e+07                     98.543349        449.928319
# 3                2.760638e+07                     62.041311        422.168612
# 4                4.642052e+07                   1131.761687        145.098913
# ..                        ...                           ...               ...
# 137              3.454407e+07                    123.696540        348.195147
# 138              3.551248e+07                    188.272075        269.608525
# 139              4.271202e+07                    257.791912        264.456991
# 140              3.457366e+07                    234.419286        290.229193
# 141              3.266546e+07                    312.893088        336.061728
#
#      Gaze point Y std  Gaze point left X std  Gaze point left Y std  \
# 0          184.022517             266.123348             186.790705
# 1          229.681948             290.183399             228.411449
# 2          296.600542             454.054157             292.848413
# 3          291.750382             425.820691             292.843381
# 4          191.266395             144.758837             190.017291
# ..                ...                    ...                    ...
# 137        263.231043             348.720574             266.853183
# 138        300.558986             271.133153             298.431022
# 139        268.899033             270.310276             267.858520
# 140        276.130932             295.652202             274.167354
# 141        320.260789             343.123426             325.584783
#
#      Gaze point right X std  Gaze point right Y std  Fixation point X std  \
# 0                260.009995              181.425624            263.789115
# 1                291.828613              225.005425            289.322105
# 2                336.000224              241.876018            451.336330
# 3                417.786224              289.088964            417.652184
# 4                144.851690              191.268911            140.586349
# ..                      ...                     ...                   ...
# 137              359.437361              269.704541            318.768719
# 138              267.432735              300.266022            202.240151
# 139              255.786411              268.392691            218.218237
# 140              278.200379              278.856312            232.850603
# 141              340.615397              316.919569            273.884071
#
#      Fixation point Y std  ...  Gaze point left X (MCSnorm) std  \
# 0              181.442909  ...                       914.774328
# 1              222.149891  ...                       911.315023
# 2              291.431232  ...                      1087.324546
# 3              286.011741  ...                       715.041518
# 4              192.131189  ...                       559.320141
# ..                    ...  ...                              ...
# 137            262.027804  ...                      1086.368688
# 138            264.436224  ...                       997.211804
# 139            255.283896  ...                      1024.940335
# 140            258.327262  ...                       863.540734
# 141            247.208021  ...                       833.848432
#
#      Gaze point left Y (MCSnorm) std  Gaze point right X (MCSnorm) std  \
# 0                         998.498528                        892.535726
# 1                        1019.156885                        922.290747
# 2                        1115.153046                        618.195177
# 3                         812.663985                        689.703259
# 4                         866.400883                        500.304828
# ..                               ...                               ...
# 137                       997.565094                       1069.764207
# 138                      1090.325773                       1034.690912
# 139                      1014.530252                       1108.573224
# 140                       940.222160                        961.075614
# 141                       846.563440                       1005.467151
#
#      Gaze point right Y (MCSnorm) std  Fixation point X (MCSnorm) std  \
# 0                          939.216928                       47.004623
# 1                         1061.481171                       39.226810
# 2                          710.900950                       43.546304
# 3                          769.998594                       26.073817
# 4                          714.166929                       14.823745
# ..                                ...                             ...
# 137                       1030.860348                       41.084894
# 138                       1148.950074                       37.916347
# 139                       1155.032959                       54.374087
# 140                       1087.453509                       34.966950
# 141                       1032.868704                       30.226440
#
#      Fixation point Y (MCSnorm) std  Validity left count  \
# 0                         48.309219                 7222
# 1                         40.479258                 7296
# 2                         42.750270                 7255
# 3                         27.522852                 6100
# 4                         15.325697                 9605
# ..                              ...                  ...
# 137                       41.397785                 7398
# 138                       42.991139                 7248
# 139                       56.560900                 8828
# 140                       42.334175                 7446
# 141                       30.302762                 7118
#
#      Validity right count  Eye movement type count  Total Score original
# 0                    7222                     7222                    76
# 1                    7296                     7296                    76
# 2                    7255                     7255                    76
# 3                    6100                     6100                    76
# 4                    9605                     9605                   102
# ..                    ...                      ...                   ...
# 137                  7398                     7398                   110
# 138                  7248                     7248                    93
# 139                  8828                     8828                    93
# 140                  7446                     7446                    93
# 141                  7118                     7118                    93
#
# [142 rows x 47 columns]

# %% [markdown]
# Fitting the dataframe into the Random Forest Classifier using leave-one-out cross-validation iterator.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import LeaveOneOut

# Assuming your dataset is already imported into a Pandas dataframe called `new_df`
X = new_df.drop("Total Score original", axis=1) # assuming the name of the target variable is 'target_variable'
y = new_df["Total Score original"]

# Create an instance of the Random Forest model
rf = RandomForestClassifier()

# Create a leave-one-out cross-validation iterator
loo = LeaveOneOut()

# Initialize an empty list to store the scores
scores = []

# Iterate over the splits and train/validate the model
for train_index, test_index in loo.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    rf.fit(X_train, y_train)
    score = rf.score(X_test, y_test)
    scores.append(score)

# Compute the mean score across all splits
mean_score = sum(scores) / len(scores)
print("Mean accuracy:", mean_score)
# Out:
# Mean accuracy: 0.5211267605633803

# %% [markdown]
# Fitting the dataframe into the Logistic Regression using leave-one-out cross-validation iterator.

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import LeaveOneOut

# Assuming your dataset is already imported into a Pandas dataframe called `new_df`
X = new_df.drop("Total Score original", axis=1) # assuming the name of the target variable is 'target_variable'
y = new_df["Total Score original"]

# Create an instance of the logistic regression model
logreg = LogisticRegression()

# Create a leave-one-out cross-validation iterator
loo = LeaveOneOut()

# Initialize an empty list to store the scores
scores = []

# Iterate over the splits and train/validate the model
for train_index, test_index in loo.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    logreg.fit(X_train, y_train)
    score = logreg.score(X_test, y_test)
    scores.append(score)

# Compute the mean score across all splits
mean_score = sum(scores) / len(scores)
print("Mean accuracy:", mean_score)
# Out:
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Python3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Mean accuracy: 0.16901408450704225
